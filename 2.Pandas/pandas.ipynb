# %%
import pandas as pd

Data={'Name':'Jai','Age':31,'Dept':'NDT'}
print(Data)

df=pd.DataFrame (Data,index=[0])
df.head()
# Out:
# {'Name': 'Jai', 'Age': 31, 'Dept': 'NDT'}
#   Name  Age Dept
# 0  Jai   31  NDT

# %%
import pandas as pd

Data={'Name':'Jai','Age':31,'Dept':'NDT'}
print(Data)

df=pd.Series (Data)
df.head()
# Out:
# {'Name': 'Jai', 'Age': 31, 'Dept': 'NDT'}
# Name    Jai
# Age      31
# Dept    NDT
# dtype: object

# %%
import pandas as pd

Data={'Name':'Jai','Age':31,'Dept':'NDT'}
print(Data)

df=pd.DataFrame (Data,index=['data_01'])
df.head()
# Out:
# {'Name': 'Jai', 'Age': 31, 'Dept': 'NDT'}
#         Name  Age Dept
# data_01  Jai   31  NDT

# %%
import pandas as pd

Data={'Name':'Jai','Age':31,'Dept':'NDT'}
print(Data)

df=pd.DataFrame (Data,columns=['Name'],index=[1])
df.head()
# Out:
# {'Name': 'Jai', 'Age': 31, 'Dept': 'NDT'}
#   Name
# 1  Jai

# %%
import pandas as pd

Data={'Name':'John','Age':33,'Job':'NDT inspector'}
print(Data)

df=pd.DataFrame (Data,index=[0])
df.head()
# Out:
# {'Name': 'John', 'Age': 33, 'Job': 'NDT inspector'}
#    Name  Age            Job
# 0  John   33  NDT inspector

# %%
df=pd.read_csv("Data/namelist.csv")
df.head()
# Out:
#    sno    name  age location
# 0    1    ragu   21   trichy
# 1    2    ravi   23  chennai
# 2    3     ram   34   trichy
# 3    4  rajesh   44  chennai

# %%
df=pd.read_csv('Data/pokemon_data.csv')
print(df.to_string())
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      1                  Bulbasaur     Grass    Poison   45      49       49       65       65     45           1      False
# 1      2                    Ivysaur     Grass    Poison   60      62       63       80       80     60           1      False
# 2      3                   Venusaur     Grass    Poison   80      82       83      100      100     80           1      False
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123      122      120     80           1      False
# 4      4                 Charmander      Fire       NaN   39      52       43       60       50     65           1      False
# 5      5                 Charmeleon      Fire       NaN   58      64       58       80       65     80           1      False
# ...

# %%
df=pd.read_json("Data/poke.json")
print(df.to_string())
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0      1                  Bulbasaur     Grass    Poison   45      49       49       65       65     45           1      False    318
# 1      2                    Ivysaur     Grass    Poison   60      62       63       80       80     60           1      False    405
# 2      3                   Venusaur     Grass    Poison   80      82       83      100      100     80           1      False    525
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123      122      120     80           1      False    625
# 4      4                 Charmander      Fire      None   39      52       43       60       50     65           1      False    309
# 5      5                 Charmeleon      Fire      None   58      64       58       80       65     80           1      False    405
# ...

# %%
df=pd.read_csv('Data/poke_modified1.csv')
print(df.to_string())
# Out:
#      Unnamed: 0    #                       Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0             0    1                  Bulbasaur     Grass    Poison   45      49       49       65       65     45           1      False    318
# 1             1    2                    Ivysaur     Grass    Poison   60      62       63       80       80     60           1      False    405
# 2             2    3                   Venusaur     Grass    Poison   80      82       83      100      100     80           1      False    525
# 3             3    3      VenusaurMega Venusaur     Grass    Poison   80     100      123      122      120     80           1      False    625
# 4             4    4                 Charmander      Fire       NaN   39      52       43       60       50     65           1      False    309
# ...

# %%
df=pd.read_csv('Data/annual-enterprise-survey-2024-financial-year-provisional.csv')
df.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 55615  Food product manufacturing  Percentage           H37
# 55616  Food product manufacturing  Percentage           H38
# 55617  Food product manufacturing  Percentage           H39
# 55618  Food product manufacturing  Percentage           H40
# 55619  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 55615                          Quick ratio  Financial ratios    52
# 55616  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
# %pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_excel('Data/FSI-2023-DOWNLOAD.xlsx')
print(df.to_string())
df.T
# Out:
#                        Country  Year   Rank  Total  S1: Demographic Pressures  S2: Refugees and IDPs  C3: Group Grievance  E3: Human Flight and Brain Drain  E2: Economic Inequality  E1: Economy  P1: State Legitimacy  P2: Public Services  P3: Human Rights  C1: Security Apparatus  C2: Factionalized Elites  X1: External Intervention
# 0                      Somalia  2023    1st  111.9                       10.0                    9.0                  8.7                               8.6                      9.1          9.5                   9.6                  9.8               9.0                     9.5                      10.0                        9.1
# ...

# %%
df=pd.read_excel("Data/FSI-2023-DOWNLOAD.xlsx")
print(df.to_string())
# Out:
#                        Country  Year   Rank  Total  S1: Demographic Pressures  S2: Refugees and IDPs  C3: Group Grievance  E3: Human Flight and Brain Drain  E2: Economic Inequality  E1: Economy  P1: State Legitimacy  P2: Public Services  P3: Human Rights  C1: Security Apparatus  C2: Factionalized Elites  X1: External Intervention
# 0                      Somalia  2023    1st  111.9                       10.0                    9.0                  8.7                               8.6                      9.1          9.5                   9.6                  9.8               9.0                     9.5                      10.0                        9.1
# ...

# %%
df=pd.read_csv('Data/poke_modified1.csv')
print(df.to_string())
# Out:
#      Unnamed: 0    #                       Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0             0    1                  Bulbasaur     Grass    Poison   45      49       49       65       65     45           1      False    318
# 1             1    2                    Ivysaur     Grass    Poison   60      62       63       80       80     60           1      False    405
# 2             2    3                   Venusaur     Grass    Poison   80      82       83      100      100     80           1      False    525
# 3             3    3      VenusaurMega Venusaur     Grass    Poison   80     100      123      122      120     80           1      False    625
# 4             4    4                 Charmander      Fire       NaN   39      52       43       60       50     65           1      False    309
# ...

# %%
df=pd.read_json("Data/poke.json")
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire    None  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df=pd.read_csv("Data/Admin upload sample.txt",delimiter='*')
print(df)
df.T
# Out:
#    First name\tLast name\tDate of birth\tGender\tStudent ID\tStudent phone\tStudent email\tClass name\tTeacher first name\tTeacher last name\tTeacher email\tGuardian first name\tGuardian last name\tGuardian email\tGuardian phone\tGuardian first name 2\tGuardian last name 2\tGuardian email 2\tGuardian phone 2\tInfo 1\tInfo 2\tInfo 3\tInfo 4\tInfo 5\tInfo 6\tInfo 7\tInfo 8\tInfo 9\tInfo 10
# 0   Joe\tSmith\t11/02/2006\tMale\t88261\t555444114...
# 1   Joe\tSmith\t11/02/2006\tMale\t88261\t555444114...
# 2   Liz\tHernadez\t05/12/2006\tFemale\t88262\t5551...
# 3   Liz\tHernadez\t05/12/2006\tFemale\t88262\t5551...
# 4   Charles\tBakely\t08/18/2006\tMale\t88264\t5556...
# 5   Charles\tBakely\t08/18/2006\tMale\t88264\t5556...
# 6   Cindy\tYe\t09/11/2007\tFemale\t88721\t55577862...
# 7   Cindy\tYe\t09/11/2007\tFemale\t88721\t55577862...
# 8   Mark\tRomney\t12/11/2005\tMale\t88222\t5553334...
# 9   Mark\tRomney\t12/11/2005\tMale\t88222\t5553334...
# ...

# %%
df=pd.read_csv("Data/Admin upload sample.txt",delimiter='\t')
print(df)
# Out:
#    First name Last name Date of birth  Gender  Student ID  Student phone  \
# 0         Joe     Smith    11/02/2006    Male       88261     5554441142
# 1         Joe     Smith    11/02/2006    Male       88261     5554441142
# 2         Liz  Hernadez    05/12/2006  Female       88262     5551112399
# 3         Liz  Hernadez    05/12/2006  Female       88262     5551112399
# 4     Charles    Bakely    08/18/2006    Male       88264     5556662877
# 5     Charles    Bakely    08/18/2006    Male       88264     5556662877
# 6       Cindy        Ye    09/11/2007  Female       88721     5557786255
# 7       Cindy        Ye    09/11/2007  Female       88721     5557786255
# 8        Mark    Romney    12/11/2005    Male       88222     5553334621
# 9        Mark    Romney    12/11/2005    Male       88222     5553334621
# 10      Julie    Wilson    05/19/2006  Female       88266     5559987211
# 11      Julie    Wilson    05/19/2006  Female       88266     5559987211
#
# ...

# %%
import pandas as pd

df=pd.read_excel("Data/fsi-2006.xlsx")
print(df)
# Out:
#                        Country       Year   Rank  Total  \
# 0                        Sudan 2006-01-01    1st  112.3
# 1    Congo Democratic Republic 2006-01-01    2nd  110.1
# 2                Cote d'Ivoire 2006-01-01    3rd  109.2
# 3                         Iraq 2006-01-01    4th  109.0
# 4                     Zimbabwe 2006-01-01    5th  108.9
# ..                         ...        ...    ...    ...
# 141               Switzerland  2006-01-01  142nd   18.7
# 142                   Ireland  2006-01-01  143rd   18.6
# 143                   Finland  2006-01-01  144th   18.2
# 144                    Sweden  2006-01-01  144th   18.2
# 145                    Norway  2006-01-01  146th   16.8
#
#      C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                       9.8                       9.1                  9.7
# 1                       9.8                       9.6                  9.1
# ...

# %%
df=pd.read_json("Data/studentmarks.json")
df.T
# Out:
#                                                           0  \
# students  {'id': 1, 'name': 'Arun Kumar', 'class': '10A'...
#
#                                                           1  \
# students  {'id': 2, 'name': 'Priya Sharma', 'class': '10...
#
#                                                           2
# students  {'id': 3, 'name': 'Ravi Raj', 'class': '10B', ...

# %%
import pandas as pd

df=pd.read_excel("Data/Dataset_supermarket_sales.xlsx")
print(df.head())
df.T
# Out:
#     Invoice ID Branch     City Customer type  Gender            Product line  \
# 0  750-67-8428      A   Trichy        Member  Female       Health and beauty
# 1  226-31-3081      C  Chennai        Normal  Female  Electronic accessories
# 2  631-41-3108      A   Trichy        Normal    Male      Home and lifestyle
# 3  123-19-1176      A   Trichy        Member    Male       Health and beauty
# 4  373-73-7910      A   Trichy        Normal    Male       Sports and travel
#
#    Unit price  Quantity   Tax 5%     Total    cogs                 Date  \
# 0       74.69         7  26.1415  548.9715  522.83  2019-05-01 00:00:00
# 1       15.28         5   3.8200   80.2200   76.40  2019-08-03 00:00:00
# 2       46.33         7  16.2155  340.5255  324.31  2019-03-03 00:00:00
# 3       58.22         8  23.2880  489.0480  465.76            1/27/2019
# 4       86.31         7  30.2085  634.3785  604.17  2019-08-02 00:00:00
#
#        Time      Payment  Rating
# 0  13:08:00      Ewallet     9.1
# ...
